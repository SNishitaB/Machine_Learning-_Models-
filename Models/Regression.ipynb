# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ecf39bfa-a187-4f4a-8457-fbfb41ce2661" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ecf39bfa-a187-4f4a-8457-fbfb41ce2661">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
temp_data = pd.read_csv("temperatures.csv")

# %%
temp_data
# Out:
#      YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP  \
# 0    1901  22.40  24.14  29.07  31.91  33.41  33.18  31.21  30.39  30.47
# 1    1902  24.93  26.58  29.77  31.78  33.73  32.91  30.92  30.73  29.80
# 2    1903  23.44  25.03  27.83  31.39  32.91  33.00  31.34  29.98  29.85
# 3    1904  22.50  24.73  28.21  32.02  32.64  32.07  30.36  30.09  30.04
# 4    1905  22.00  22.83  26.68  30.01  33.32  33.25  31.44  30.68  30.12
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 112  2013  24.56  26.59  30.62  32.66  34.46  32.44  31.07  30.76  31.04
# 113  2014  23.83  25.97  28.95  32.74  33.77  34.15  31.85  31.32  30.68
# 114  2015  24.58  26.89  29.07  31.87  34.09  32.48  31.88  31.52  31.55
# 115  2016  26.94  29.72  32.62  35.38  35.72  34.03  31.64  31.79  31.66
# 116  2017  26.45  29.46  31.60  34.95  35.84  33.82  31.88  31.72  32.22
#
#        OCT    NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# ...

# %%
#The describe() function generates various summary statistics of the numerical columns in the DataFrame.
#These statistics include count, mean, standard deviation, minimum, 25th percentile (Q1), median (50th percentile or Q2), 75th percentile (Q3), and maximum values.
temp_data.describe()
# Out:
#               YEAR         JAN         FEB         MAR         APR  \
# count   117.000000  117.000000  117.000000  117.000000  117.000000
# mean   1959.000000   23.687436   25.597863   29.085983   31.975812
# std      33.919021    0.834588    1.150757    1.068451    0.889478
# min    1901.000000   22.000000   22.830000   26.680000   30.010000
# 25%    1930.000000   23.100000   24.780000   28.370000   31.460000
# 50%    1959.000000   23.680000   25.480000   29.040000   31.950000
# 75%    1988.000000   24.180000   26.310000   29.610000   32.420000
# max    2017.000000   26.940000   29.720000   32.620000   35.380000
#
#               MAY         JUN         JUL         AUG         SEP         OCT  \
# count  117.000000  117.000000  117.000000  117.000000  117.000000  117.000000
# mean    33.565299   32.774274   31.035897   30.507692   30.486752   29.766581
# std      0.724905    0.633132    0.468818    0.476312    0.544295    0.705492
# ...

# %%
temp_data.dtypes
# Out:
# YEAR         int64
# JAN        float64
# FEB        float64
# MAR        float64
# APR        float64
# MAY        float64
# JUN        float64
# JUL        float64
# AUG        float64
# SEP        float64
# OCT        float64
# NOV        float64
# DEC        float64
# ANNUAL     float64
# JAN-FEB    float64
# MAR-MAY    float64
# JUN-SEP    float64
# OCT-DEC    float64
# dtype: object

# %%
temp_data.columns
# Out:
# Index(['YEAR', 'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP',
#        'OCT', 'NOV', 'DEC', 'ANNUAL', 'JAN-FEB', 'MAR-MAY', 'JUN-SEP',
#        'OCT-DEC'],
#       dtype='object')

# %%
temp_data.isnull().sum()
# Out:
# YEAR       0
# JAN        0
# FEB        0
# MAR        0
# APR        0
# MAY        0
# JUN        0
# JUL        0
# AUG        0
# SEP        0
# OCT        0
# NOV        0
# DEC        0
# ANNUAL     0
# JAN-FEB    0
# MAR-MAY    0
# JUN-SEP    0
# OCT-DEC    0
# dtype: int64

# %%
top5_data = temp_data.nlargest(5, "ANNUAL")

# %%
top5_data
# Out:
#      YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP  \
# 115  2016  26.94  29.72  32.62  35.38  35.72  34.03  31.64  31.79  31.66
# 116  2017  26.45  29.46  31.60  34.95  35.84  33.82  31.88  31.72  32.22
# 108  2009  25.27  27.75  30.57  33.09  34.09  33.73  31.77  31.84  31.60
# 101  2002  24.56  26.18  30.59  33.51  35.08  33.46  32.76  31.04  31.05
# 94   1995  24.44  26.93  29.92  32.83  34.45  34.48  31.39  30.91  31.24
#
#        OCT    NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# 115  31.98  30.11  28.01   31.63    28.33    34.57    32.28    30.03
# 116  32.29  29.60  27.18   31.42    27.95    34.13    32.41    29.69
# 108  30.75  27.59  25.53   30.30    26.51    32.57    32.24    27.96
# 101  31.02  28.86  25.88   30.23    25.37    33.06    32.02    28.36
# 94   30.93  28.51  26.21   30.18    25.68    32.40    32.01    28.52

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
sns.barplot(x = top5_data.YEAR, y = top5_data.ANNUAL)
plt.title("Top 5 temperatures")
# Out:
# Text(0.5, 1.0, 'Top 5 temperatures')

# %%
sns.set_style("whitegrid")

# %%
sns.boxplot(y = "YEAR", data = temp_data)
# Out:
# <Axes: ylabel='YEAR'>

# %%
sns.boxplot(x = "MAY", data = temp_data)
# Out:
# <Axes: xlabel='MAY'>

# %%
sns.heatmap(data = temp_data, vmin = 20, vmax = 40)
# Out:
# <Axes: >

# %%
sns.histplot(x = "YEAR", y = "ANNUAL", data = temp_data)
# Out:
# <Axes: xlabel='YEAR', ylabel='ANNUAL'>

# %%
sns.scatterplot(x = "YEAR", y = "ANNUAL", data = temp_data)
# Out:
# <Axes: xlabel='YEAR', ylabel='ANNUAL'>

# %%
from sklearn import linear_model,metrics

# %%
X = temp_data[["YEAR"]]

# %%
X
# Out:
#      YEAR
# 0    1901
# 1    1902
# 2    1903
# 3    1904
# 4    1905
# ..    ...
# 112  2013
# 113  2014
# 114  2015
# 115  2016
# 116  2017
#
# [117 rows x 1 columns]

# %%
Y = temp_data[["JAN"]]

# %%
Y
# Out:
#        JAN
# 0    22.40
# 1    24.93
# 2    23.44
# 3    22.50
# 4    22.00
# ..     ...
# 112  24.56
# 113  23.83
# 114  24.58
# 115  26.94
# 116  26.45
#
# [117 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 30)

# %%
len(X_train)
# Out:
# 93

# %%
len(X_test)
# Out:
# 24

# %%
reg = linear_model.LinearRegression()

# %%
model = reg.fit(X_train, Y_train)

# %%
Y_pred = model.predict(X_test)

# %%
Y_pred
# Out:
# array([[24.15949301],
#        [22.84799543],
#        [22.83309205],
#        [24.30852683],
#        [22.9523191 ],
#        [24.47246403],
#        [23.31000026],
#        [24.45756065],
#        [24.36814036],
#        [23.83161862],
#        [23.59316451],
#        [23.72729495],
#        [23.66768142],
#        [23.14606306],
#        [24.4128505 ],
#        [23.13115968],
#        [24.27872007],
#        [23.29509688],
#        [23.81671524],
#        [24.32343021],
#        [23.77200509],
#        [23.19077321],
#        [24.07007272],
#        [24.09987949]])

# %%
Y_test
# Out:
#        JAN
# 89   24.24
# 1    24.93
# 0    22.40
# 99   24.44
# 8    22.67
# 110  24.18
# 32   22.85
# 109  24.89
# 103  23.89
# 67   22.67
# 51   23.91
# 60   24.14
# 56   22.98
# 21   22.96
# 106  25.19
# 20   23.57
# 97   23.95
# 31   24.13
# 66   23.72
# 100  24.36
# 63   23.06
# 24   22.56
# 83   23.59
# 85   23.61

# %%
plt.scatter(X_train, Y_train)
plt.plot(X_train, reg.predict(X_train), color = "RED")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(X_train, Y_train)
plt.plot(X_train, reg.predict(X_train), color = "ORANGE")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print(model.intercept_)
# Out:
# [-5.49823644]

# %%
print(model.coef_)
# Out:
# [[0.01490338]]

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
print(mean_absolute_error(Y_test, Y_pred))
# Out:
# 0.5109571689253425

# %%
print(mean_squared_error(Y_test, Y_pred))
# Out:
# 0.4355735132045715

# %%
print(r2_score(Y_test, Y_pred))
# Out:
# 0.2801509887449809
